# %%
import pandas as pd
df = pd.read_csv("spain_part_1_books.csv")

# %%
pd.options.display.max_colwidth = 300

# %%
import numpy as np

# %%
#df["book"] = np.nan

# %%
#df["chapter"] = np.nan

# %%
pd.set_option("display.max_rows", None)

# %%
df.loc[df['page_number']==3, ['book']] = ''

# %%
for x in range(722):
    if x >=82 and x <=82:
        df.loc[df['page_number']==x, ['chapter']] = 'chapter_2'

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                  This is a reproduction of a library book that was digitized  by Google as part of an ongoing effort to preserve the  information in books and make it universally accessible.    Google books    https://books.google.com
# 1
# 2                                                                                                                                                                                                                                           ae  a IVEIURIE    as |    Sig              HARVARD  COLLEGE  LIBRARY
# ...

# %%
df.to_csv('spain_part_1_books_ch1.csv', index=False, header=True)

# %%
text[300]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 text[300]
#
# NameError: name 'text' is not defined
